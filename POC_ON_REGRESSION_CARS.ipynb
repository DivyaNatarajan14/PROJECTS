# %% [markdown]
# #IMPORTING LIBRARIES

# %% [markdown]
# pandas (import pandas as pd): For handling structured data with DataFrames.
#
# numpy (import numpy as np): For numerical operations on arrays and matrices.
#
# matplotlib (import matplotlib.pyplot as plt): For creating static visualizations.
#
# seaborn (import seaborn as sb): For creating attractive statistical visualizations.
#
# Setting display options (pd.set_option): Adjusts options to display all columns and limit rows to 150 for better data exploration.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

#display all columns and rows of the dataframe
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', 150)

# %% [markdown]
# IMPORTING DATA SET
#
# Upload a file from your local machine to your Colab environment
#
# uploaded = files.upload()
#
# Download a file from your Colab environment to your local machine
#
# files.download('example.txt')

# %%
from google.colab import files
raw= files.upload()
# Out:
#      <input type="file" id="files-76e1dba0-0c0c-4b16-9221-edbfff556774" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76e1dba0-0c0c-4b16-9221-edbfff556774">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# REVIEWING THE DATASET

# %%
rdata=pd.read_csv('CarPrice_Assignment.csv')

# %% [markdown]
# SHALLOW COPYING

# %%
df=rdata.copy()

# %%
ndata=rdata.copy()

# %% [markdown]
# #EXPLORATORY DATA ANALYSIS

# %%
df.shape   #an attribute of a DataFrame that returns a tuple representing the dimensions of the DataFrame.
# Out:
# (205, 26)

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
# ...

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 200   sedan        rwd          front      109.1      188.8      68.9
# 201   sedan        rwd          front      109.1      188.8      68.8
# 202   sedan        rwd          front      109.1      188.8      68.9
# 203   sedan        rwd          front      109.1      188.8      68.9
# 204   sedan        rwd          front      109.1      188.8      68.9
#
#      carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.info() # Display concise summary of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
# Display summary for categorical data
df.describe(include='object').T
# Out:
#                count unique            top freq
# CarName          205    147  toyota corona    6
# fueltype         205      2            gas  185
# aspiration       205      2            std  168
# doornumber       205      2           four  115
# carbody          205      5          sedan   96
# drivewheel       205      3            fwd  120
# enginelocation   205      2          front  202
# enginetype       205      7            ohc  148
# cylindernumber   205      7           four  159
# fuelsystem       205      8           mpfi   94

# %%
# Display summary for numerical data
df.describe().T
# Out:
#                   count          mean          std      min      25%  \
# car_ID            205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# ...

# %%
df['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
# Extracting brands from the 'CarName' column
brands = pd.Series([x.split()[0] for x in df['CarName'].str.lower()])

# Printing the number of unique brands and the unique brands themselves
print(f'There are {brands.nunique()} unique brands, and they are:\n', brands.unique())
# Out:
# There are 27 unique brands, and they are:
#  ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'maxda' 'mazda' 'buick' 'mercury' 'mitsubishi' 'nissan' 'peugeot'
#  'plymouth' 'porsche' 'porcshce' 'renault' 'saab' 'subaru' 'toyota'
#  'toyouta' 'vokswagen' 'volkswagen' 'vw' 'volvo']

# %%
def replace_name(brands, old, new):
    brands.replace(old, new, inplace=True)

# Assuming brands is your Series
# Example:
# brands = df['CarName'].apply(lambda x: x.split()[0].lower())

# Correcting brand names
replace_name(brands, 'maxda', 'mazda')
replace_name(brands, 'porcshce', 'porsche')
replace_name(brands, 'toyouta', 'toyota')
replace_name(brands, 'vokswagen', 'volkswagen')
replace_name(brands, 'vw', 'volkswagen')

# Display unique brand names after replacement
print(f'There are {brands.nunique()} unique brands, and they are:\n', brands.unique())
# Out:
# There are 22 unique brands, and they are:
#  ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'buick' 'mercury' 'mitsubishi' 'nissan' 'peugeot' 'plymouth'
#  'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen' 'volvo']

# %%
# Drop the 'CarName' column
df.drop('CarName', axis=1, inplace=True)

# Create a new 'brand' column using the corrected brand names
df['brand'] = brands

# Display the updated DataFrame
df.iloc[105:110,-1]
# Out:
# 105     nissan
# 106     nissan
# 107    peugeot
# 108    peugeot
# 109    peugeot
# Name: brand, dtype: object

# %%
rdata.iloc[105:110,:]
# Out:
#      car_ID  symboling           CarName fueltype aspiration doornumber  \
# 105     106          3      nissan kicks      gas      turbo        two
# 106     107          1    nissan clipper      gas        std        two
# 107     108          0       peugeot 504      gas        std       four
# 108     109          0       peugeot 304   diesel      turbo       four
# 109     110          0  peugeot 504 (sw)      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 105  hatchback        rwd          front       91.3      170.7      67.9
# 106  hatchback        rwd          front       99.2      178.5      67.9
# 107      sedan        rwd          front      107.9      186.7      68.4
# 108      sedan        rwd          front      107.9      186.7      68.4
# 109      wagon        rwd          front      114.2      198.9      68.4
#
#      carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# ...

# %%
df['brand'].nunique()
# Out:
# 22

# %%
df.drop(['car_ID'], axis=1, inplace=True)

# %% [markdown]
# # ***HANDLING MISSING VALUES***

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 205, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # DETECTION OF MISSING VALUES

# %%
df.isnull().sum()
# Out:
# symboling           0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# brand               0
# dtype: int64

# %% [markdown]
# no missing values in the data frame verified by visualization

# %%
sb.heatmap(df.isnull(),cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# #UNIVARIATE ANALYSIS

# %% [markdown]
# FOR CATEGORICAL FEATURES

# %%
for column in df.select_dtypes(include='object').columns:
    # Bar chart
    plt.figure(figsize=(8, 5))
    sb.countplot(x=df[column])
    plt.title(f'Bar Chart of {column}')
    plt.xticks(rotation=45,ha='right') #ha='right' means horizontal alignment of text in right side
    plt.show()

# %% [markdown]
# NUMERICAL FEATURES

# %% [markdown]
# HISTOGRAM

# %%
for column in df.select_dtypes(include='number').columns:
# Histogram
  plt.figure(figsize=(10, 6))
  sb.histplot(df[column], kde=True, color='skyblue')#kde=True adds kernel density estimate plot
  plt.title(f'Histogram of {column}')
  plt.xlabel(column)
  plt.ylabel('Frequency')
  plt.show()

# %% [markdown]
# BOX PLOT

# %%
for column in df.select_dtypes(include='number').columns:
# Box plot --- summarizing distribution of numerical variable
  plt.figure(figsize=(8, 6))
  sb.boxplot(x=df[column], color='lightcoral')
  plt.title(f'Box Plot of {column}')
  plt.xlabel(column)
  plt.xticks(rotation=45)
  plt.show()

# %% [markdown]
# BAR CHART FOR DESCRIPTIVE STATISTICS

# %%
for column in df.select_dtypes(include='number').columns:
# Bar chart for descriptive statistics
  summary_stats = df[column].describe()
  plt.figure(figsize=(8, 6))
  sb.barplot(x=summary_stats.index, y=summary_stats.values, palette='viridis')
  plt.title(f'Descriptive Statistics of {column}')
  plt.ylabel('Value')
  plt.xticks(rotation=45,ha='right')
  plt.show()

# %% [markdown]
# KERNEL DENSITY PLOT

# %%
for column in df.select_dtypes(include='number').columns:
# Kernel Density Plot-- smooth estimate of the distribution
  plt.figure(figsize=(10, 6))
  sb.kdeplot(df[column], fill=True, color='orange')
  plt.title(f'Kernel Density Plot of {column}')
  plt.xlabel(column)
  plt.xticks(rotation=45)
  plt.show()

# %% [markdown]
# # ***BIVARIATE ANALYSIS***

# %% [markdown]
# Bivariate analysis involving a categorical and a numerical feature can be visualized using various techniques. Below are code samples for a few common visualizations:
#
# Box Plot by Category:
#
# Visualizes the distribution of a numerical variable for each category of a categorical variable.
#
# import seaborn as sns
#
# import matplotlib.pyplot as plt
#
# sns.boxplot(x='CategoricalColumn', y='NumericColumn', data=df, palette='Set2')
#
# plt.title('Box Plot by Category')
#
# plt.show()
#
# Violin Plot by Category:
#
# Similar to a box plot but includes a kernel density estimation for better distribution
#
# sns.violinplot(x='CategoricalColumn', y='NumericColumn', data=df, palette='Set2')
#
# plt.title('Violin Plot by Category')
#
# plt.show()
#
# Bar Plot with Error Bars:
#
# Displays the mean or median of the numerical variable for each category, along with error bars.
#
# sns.barplot(x='CategoricalColumn', y='NumericColumn', data=df, ci='sd', palette='Set2')
#
# plt.title('Bar Plot with Error Bars')
#
# plt.show()
#
# Point Plot:
#
# Similar to a bar plot but represents the point estimate and confidence interval.
#
# sns.pointplot(x='CategoricalColumn', y='NumericColumn', data=df, ci='sd', palette='Set2')
#
# plt.title('Point Plot')
#
# plt.show()
#
# Swarm Plot:
#
# Represents individual data points, providing a more detailed view of the distribution.
#
# sns.swarmplot(x='CategoricalColumn', y='NumericColumn', data=df, palette='Set2')
#
# plt.title('Swarm Plot')
#
# plt.show()
#
# Faceted Histograms:
#
# Displays histograms for numerical variables within each category using facets.
#
# sns.histplot(data=df, x='NumericColumn', hue='CategoricalColumn', multiple='stack', palette='Set2',
#
# bins=20)
#
# plt.title('Faceted Histograms')
#
# plt.show()
#
# These visualizations allow you to explore the relationship between a categorical and a numerical variable. Customize the column names, palette, and other parameters based on your specific dataset and analysis objectives.

# %%
df.dtypes
# Out:
# symboling             int64
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# brand                object
# dtype: object

# %%
# Numeric variables of interest
numeric_column1 = 'horsepower'
numeric_column2 = 'stroke'

# Scatter Plot
#plt.figure(figsize=(8, 6))
#sb.scatterplot(x=df[numeric_column1], y=df[numeric_column2], color='skyblue')
#plt.title(f'Scatter Plot between {numeric_column1} and {numeric_column2}')
#plt.xlabel(numeric_column1)
#lt.ylabel(numeric_column2)
#plt.show()

# Box Plot
#plt.figure(figsize=(8, 6))
#sb.boxplot(x=df[numeric_column1], y=df[numeric_column2], color='lightcoral')
#plt.title(f'Box Plot between {numeric_column1} and {numeric_column2}')
#plt.xlabel(numeric_column1)
#plt.ylabel(numeric_column2)
#plt.xticks(rotation=90)
#plt.show()

# Correlation Heatmap
numeric_column3='peakrpm'
correlation_matrix = df[[numeric_column1, numeric_column2, numeric_column3]].corr()
plt.figure(figsize=(8, 6))
sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# Pair Plot
sb.pairplot(df[[numeric_column1, numeric_column2]])
plt.suptitle(f'Pair Plot of {numeric_column1} and {numeric_column2}', y=1.02)
plt.show()

# %%
#find values with top 10 occurrences in 'CarName'
plt.figure(figsize=(15,6))
top_10 = (df['brand'].value_counts()).iloc[:20]

#create bar chart to visualize top 10 values
top_10.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Use seaborn's barplot to plot the mean 'price' for each category in the selected numeric column

# %%
for column in df.select_dtypes(include='number').columns:
    # Skip plotting 'price' vs 'price'
    if column == 'price':
        continue

    # Sum the values in the selected numeric column
    sum_values = df[column].sum()

    # Create a bar plot
    plt.figure(figsize=(25, 3))
    plt.xticks(rotation=90)

    # Use seaborn's barplot to plot the mean 'price' for each category in the selected numeric column
    sb.barplot(data=df, x=column, y='price', palette='Set2', order=df.groupby(column)['price'].mean().sort_values().index)

    plt.title(f'{column} vs Price')
    plt.show()

# %% [markdown]
# Use seaborn's barplot to plot the mean 'price' for each category in the selected numeric column

# %%
for column in df.select_dtypes(include='object').columns:
    # Sum the values in the selected numeric column
    sum_values = df[column].sum()

    # Create a bar plot
    plt.figure(figsize=(10, 5))
    plt.xticks(rotation=35,ha='right')

    # Use seaborn's barplot to plot the mean 'price' for each category in the selected numeric column
    sb.barplot(data=df, x=column, y='price', palette='Set2', order=df.groupby(column)['price'].mean().sort_values().index)

    plt.title(f'{column} vs Price')
    plt.show()

# %%
# Categorical variables of interest
cat_column1 = 'brand'
cat_column2 = 'fueltype'
# Stacked Bar Plot
cross_tab = pd.crosstab(df[cat_column1], df[cat_column2])
cross_tab.plot(kind='bar', stacked=True, colormap='viridis', figsize=(10, 6))
plt.title(f'Stacked Bar Plot of {cat_column1} by {cat_column2}')
plt.xlabel(cat_column1)
plt.ylabel('Count')
plt.show()

# %%
# Categorical variables of interest
cat_column1 = 'brand'
cat_column2 = 'enginetype'
# Grouped Bar Plot
cross_tab = pd.crosstab(df[cat_column1], df[cat_column2])
cross_tab.plot(kind='bar', figsize=(10, 6))
plt.title(f'Grouped Bar Plot of {cat_column1} by {cat_column2}')
plt.xlabel(cat_column1)
plt.ylabel('Count')
plt.show()

# %%
# Get the top 10 brands and their counts
top_brands = df['brand'].value_counts().iloc[:10]

# Create a bubble plot
plt.scatter(x=top_brands.index, y=df['stroke'].value_counts().iloc[:10], s=df['price'].iloc[:10]*10, c=df['price'].iloc[:10], alpha=0.5, cmap='viridis')

# Set labels and title
plt.title('Bubble Plot')
plt.xlabel('Brand')
plt.ylabel('Stroke')
plt.xticks(rotation=50, ha='right')

# Add colorbar
plt.colorbar(label='Price')

plt.show()

# %% [markdown]
# #STATISTICAL SUMMARY
#
# Use describe for an overview of summary statistics
# summary_stats = df.describe()
#
#  Calculate individual summary statistics
#
# mean_values = df.mean()
# median_values = df.median()
# mode_values = df.mode().iloc[0]  # Mode can return multiple values, take the first one
# variance_values = df.var()
# std_dev_values = df.std()
#
#  Display the results
#
# print("Summary Statistics:")
# summary_stats
#
# print("\nIndividual Summary Statistics:")
# print("Mean:")
# print(mean_values)
#
# print("\nMedian:")
# print(median_values)
#
# print("\nMode:")
# print(mode_values)
#
# print("\nVariance:")
# print(variance_values)
#
# print("\nStandard Deviation:")
# print(std_dev_values)

# %%
df.describe().T
# Out:
#                   count          mean          std      min      25%  \
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# citympg           205.0     25.219512     6.542142    13.00    19.00
# ...

# %%
correlation=df.corr()
plt.figure(figsize=(20,5))
sb.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()
# Out:
# <ipython-input-106-7218e3e01748>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()

# %% [markdown]
# # OUTLIERS DETECTION AND REMOVAL

# %% [markdown]
#  DETECTION

# %%
# Select numerical columns for outlier detection
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Create box plots for numerical columns
plt.figure(figsize=(12, 6))
sb.boxplot(data=df[numerical_columns])
plt.title('Box Plots for Outlier Detection')
plt.xticks(rotation=45)
plt.show()

# Create scatter plots for pairs of numerical columns
#plt.figure(figsize=(12, 8))
#sb.pairplot(df[numerical_columns])
#plt.suptitle('Pair Plots for Outlier Detection', y=1.02)
#plt.show()

# %%
# Calculate IQR for each numerical column
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# Set a multiplier for IQR (adjust as needed)
iqr_multiplier = 1.5

# Identify and remove outliers based on IQR
df_no_outliers_iqr = df[~((df < (Q1 - iqr_multiplier * IQR)) | (df > (Q3 + iqr_multiplier * IQR))).any(axis=1)]

# Display before and after
print("Before IQR Removal:")
print(df.describe())

print("\nAfter IQR Removal:")
print(df_no_outliers_iqr.describe())
# Out:
# Before IQR Removal:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# ...

# %%
# Select numerical columns for outlier detection
numerical_columns = df_no_outliers_iqr.select_dtypes(include=['float64', 'int64']).columns

# Create box plots for numerical columns
plt.figure(figsize=(12, 6))
sb.boxplot(data=df_no_outliers_iqr[numerical_columns])
plt.title('Box Plots for Outlier Detection')
plt.xticks(rotation=45)
plt.show()

# Create scatter plots for pairs of numerical columns
#plt.figure(figsize=(12, 8))
#sb.pairplot(df_no_outliers_iqr[numerical_columns])
#plt.suptitle('Pair Plots for Outlier Detection', y=1.02)
#plt.show()

# %% [markdown]
# #STANDARDIZATION

# %%
df.shape
# Out:
# (205, 25)

# %%
data=df_no_outliers_iqr.copy()

# %%
d=data['price']
c=data.drop('price',axis=1)

# %% [markdown]
# ***`STANDARDIZATION`***
#
# Standardize features by removing the mean and scaling to unit variance.
#
# Centering and scaling happen independently on each feature by computing the relevant statistics on the samples in the training set. Mean and standard deviation are then stored to be used on later data using transform.
#
# Standardization of a dataset is a common requirement for many machine learning estimators: they might behave badly if the individual features do not more or less look like standard normally distributed data (e.g. Gaussian with 0 mean and unit variance).
#
# StandardScaler is sensitive to outliers,

# %%
from sklearn.preprocessing import StandardScaler

# Identify numerical columns
numerical_columns = c.select_dtypes(include=['number']).columns

# Separate numerical columns from non-numerical columns
X_numerical = c[numerical_columns]
X_non_numerical = c.drop(columns=numerical_columns)

# Standardize numerical columns
scaler = StandardScaler()
X_numerical_standardized = pd.DataFrame(scaler.fit_transform(X_numerical), columns=numerical_columns)

# Concatenate standardized numerical columns with non-numerical columns
df_standardized = pd.concat([X_numerical_standardized, X_non_numerical], axis=1)

# %%
df_std=pd.concat([df_standardized,d], axis =1)

# %% [markdown]
# #ORDINAL ENCODING

# %%
df_std.dtypes
# Out:
# symboling           float64
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight          float64
# enginesize          float64
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower          float64
# peakrpm             float64
# citympg             float64
# highwaympg          float64
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# enginetype           object
# cylindernumber       object
# fuelsystem           object
# brand                object
# price               float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
# Select categorical columns for label encoding
categorical_columns = df_std.select_dtypes(include=['object']).columns

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to each categorical column
df_encodeds = df_std.copy()
df_encodeds[categorical_columns] = df_encodeds[categorical_columns].apply(lambda col: label_encoder.fit_transform(col))


#apply(lambda col: label_encoder.fit_transform(col)): This applies the label encoding transformation to each column in the selected set of categorical columns.
# Here's a breakdown of this part:

#lambda col: label_encoder.fit_transform(col): This lambda function takes each column (col)
#and applies the label encoding transformation using label_encoder.fit_transform. The fit_transform method fits the encoder to the unique values in the column and transforms those values into numeric labels.

#The result is a DataFrame with the same structure as the original df_encoded, but with the categorical columns replaced by their corresponding label-encoded versions.

# %%
df_encodeds.dtypes
# Out:
# symboling           float64
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight          float64
# enginesize          float64
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower          float64
# peakrpm             float64
# citympg             float64
# highwaympg          float64
# fueltype              int64
# aspiration            int64
# doornumber            int64
# carbody               int64
# drivewheel            int64
# enginelocation        int64
# enginetype            int64
# cylindernumber        int64
# fuelsystem            int64
# brand                 int64
# price               float64
# dtype: object

# %%
df_encodeds.shape
# Out:
# (184, 25)

# %%
df_encodeds.head()
# Out:
#    symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0   1.750785  -2.005234  -0.252339 -0.791926  -1.972420    0.346204
# 1   1.750785  -2.005234  -0.252339 -0.791926  -1.972420    0.346204
# 2   0.122965  -0.697695  -0.027138  0.135881  -0.487094    1.029973
# 3   0.936875   0.476875   0.479565  0.599785   0.296828   -0.178433
# 4   0.936875   0.388228   0.479565  0.732329   0.296828    1.032459
#
#    enginesize  boreratio    stroke  compressionratio  horsepower   peakrpm  \
# 0    0.548082   0.829953 -3.171746          0.053945    0.480246 -0.540853
# 1    0.548082   0.829953 -3.171746          0.053945    0.480246 -0.540853
# 2    1.390309  -2.389303  1.102793          0.053945    1.950001 -0.540853
# 3   -0.255863  -0.311049  0.724036          1.937962    0.172623  0.685550
# 4    0.777780  -0.311049  0.724036         -1.830071    0.616968  0.685550
#
#     citympg  highwaympg  fueltype  aspiration  doornumber  carbody  \
# ...

# %% [markdown]
# without standardization

# %%
from sklearn.preprocessing import LabelEncoder
# Select categorical columns for label encoding
categorical_columns = data.select_dtypes(include=['object']).columns

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to each categorical column
df_encoded = data.copy()
df_encoded[categorical_columns] = df_encoded[categorical_columns].apply(lambda col: label_encoder.fit_transform(col))


#apply(lambda col: label_encoder.fit_transform(col)): This applies the label encoding transformation to each column in the selected set of categorical columns.
# Here's a breakdown of this part:

#lambda col: label_encoder.fit_transform(col): This lambda function takes each column (col)
#and applies the label encoding transformation using label_encoder.fit_transform. The fit_transform method fits the encoder to the unique values in the column and transforms those values into numeric labels.

#The result is a DataFrame with the same structure as the original df_encoded, but with the categorical columns replaced by their corresponding label-encoded versions.

# %%
df_encoded.shape
# Out:
# (139, 25)

# %%
df_encoded.head()
# Out:
#    symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0          3         0           0           1        0           2
# 1          3         0           0           1        0           2
# 2          1         0           0           1        2           2
# 3          2         0           0           0        3           1
# 4          2         0           0           0        3           0
#
#    enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0               0       88.6      168.8      64.1       48.8        2548
# 1               0       88.6      168.8      64.1       48.8        2548
# 2               0       94.5      171.2      65.5       52.4        2823
# 3               0       99.8      176.6      66.2       54.3        2337
# 4               0       99.4      176.6      66.4       54.3        2824
#
#    enginetype  cylindernumber  enginesize  fuelsystem  boreratio  stroke  \
# ...

# %% [markdown]
# #DATA PARTITIONING

# %%
X = df_encoded.drop('price', axis=1)

y=df_encoded['price']

# %% [markdown]
# The dataset will be divided into 80% for training and 20% for testing.

# %%
# Split data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# MODEL BUILDING

# %% [markdown]
# Multilinear Regression:
#
# Multilinear Regression is a statistical method used to model the relationship between multiple independent variables and a dependent variable by fitting a linear equation to observed data. In simple terms, it extends simple linear regression, where you have one independent variable, to multiple independent variables.

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
ypre=lr.predict(X_test)
ypre
# Out:
# array([17481.14202291,  6854.8178923 ,  9672.24177836, 17526.90868928,
#        12861.11025288,  7493.89715595, 16107.70174812,  6772.20387994,
#         6084.87891556,  7748.8226842 , 12436.58660658, 15954.93544528,
#        18257.37008665,  9245.53324835,  7107.13472544,  6965.43669749,
#         7379.76657855,  8025.84880199, 16684.39990639, 11722.17538683,
#        13795.47054457, 16954.01926752, 18153.39828364, 12130.58910549,
#         8127.04290112,  7433.2217811 , 15459.93059056,  8542.33171702])

# %%
y_test
# Out:
# 200    16845.0
# 93      7349.0
# 41     12945.0
# 179    15998.0
# 55     10945.0
# 20      6575.0
# 65     18280.0
# 95      7799.0
# 190     9980.0
# 78      6669.0
# 172    17669.0
# 195    13415.0
# 109    12440.0
# 27      8558.0
# 122     7609.0
# 96      7499.0
# 19      6295.0
# 37      7895.0
# 199    18950.0
# 169     9989.0
# 46     11048.0
# 178    16558.0
# 106    18399.0
# 4      17450.0
# 100     9549.0
# 36      7295.0
# 197    16515.0
# 86      8189.0
# Name: price, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(y_test,ypre)
mse=mean_squared_error(y_test,ypre)
print('MAE= ' ,mae)
print('MSE = ',mse)
# Out:
# MAE=  1755.1853797173746
# MSE =  5631305.162092975

# %%
sb.regplot(x=y_test, y=ypre)
#sb.regplot function is used to create a scatter plot with a regression line fit to the data.
#
#Make sure to replace the example data with your actual data.

# Add labels and a title
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Regression Plot of Actual vs. Predicted Values")

# Show the plot
plt.show()

# %% [markdown]
# POLYNOMIAL REGRESSION

# %% [markdown]
# Polynomial Regression is a form of regression analysis in which the relationship between the independent variable X and the dependent variable Y is modeled as an n-th degree polynomial.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Polynomial features (degree can be adjusted)
degree = 2
poly_features = PolynomialFeatures(degree=degree)
X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

# Instantiate and fit the Polynomial Regression model
poly_regressor = LinearRegression()
poly_regressor.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions
y_pred = poly_regressor.predict(X_test_poly)
y_pred
# Out:
# array([  3519.43189077,   6926.45124915,  13007.43036407, -62903.32553406,
#         11844.99999994,   8773.6996066 ,  -4550.28081912,  12736.73899766,
#        -34477.08854996,  12886.98810684,  30731.71869909,   3917.08128826,
#        -33723.92815734,  25870.03589771,  24592.85696621,   6417.16952117,
#         13768.26017801,   1366.00399787,  60902.82748216,   3927.43505089,
#        157269.6548075 , -67354.36575666,  43113.52212644,   1360.11614599,
#          3144.87083967,  63554.62920297,   8375.13361293,  10775.95059518])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
print('MAE= ' ,mae)
print('MSE = ',mse)
# Out:
# MAE=  24453.628866100807
# MSE =  1657746966.3209882

# %%
sb.regplot(x=y_test, y=y_pred)
#sb.regplot function is used to create a scatter plot with a regression line fit to the data.
#
#Make sure to replace the example data with your actual data.

# Add labels and a title
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Polynomial Regression Plot of Actual vs. Predicted Values")

# Show the plot
plt.show()

# %% [markdown]
# with standardization model building is predicted

# %%
df_encodeds.shape
# Out:
# (184, 25)

# %%
df_encodeds.dropna(inplace=True)

# %%
df_encodeds.shape
# Out:
# (94, 25)

# %%
df_encodeds.isna().sum()
# Out:
# symboling           0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# enginetype          0
# cylindernumber      0
# fuelsystem          0
# brand               0
# price               0
# dtype: int64

# %%
xs = df_encodeds.drop('price', axis=1)

ys=df_encodeds['price']

# %%
xs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94 entries, 0 to 137
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         94 non-null     float64
#  1   wheelbase         94 non-null     float64
#  2   carlength         94 non-null     float64
#  3   carwidth          94 non-null     float64
#  4   carheight         94 non-null     float64
#  5   curbweight        94 non-null     float64
#  6   enginesize        94 non-null     float64
#  7   boreratio         94 non-null     float64
#  8   stroke            94 non-null     float64
#  9   compressionratio  94 non-null     float64
#  10  horsepower        94 non-null     float64
#  11  peakrpm           94 non-null     float64
#  12  citympg           94 non-null     float64
#  13  highwaympg        94 non-null     float64
#  14  fueltype          94 non-null     int64
#  15  aspiration        94 non-null     int64
# ...

# %%
# Split data into train and test sets
from sklearn.model_selection import train_test_split
xs_train, xs_test, ys_train, ys_test = train_test_split(xs, ys, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x_trainss = ss.fit_transform(xs_train)
x_testss = ss.transform(xs_test)

# %% [markdown]
# MODEL BUILDING

# %% [markdown]
# Multilinear Regression:

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xs_train,ys_train)
# Out:
# LinearRegression()

# %%
yspre=lr.predict(xs_test)
yspre
# Out:
# array([ 8348.72195014,  4808.98587797,  7016.68983107,  2297.53264827,
#        17627.05437824,  3336.17261294,  7589.96021817, 10115.96266058,
#        18477.43123334, 13332.43985654, 12497.50900754,  6075.19491676,
#        14594.53523833, 10494.78852821,  6952.11723916,  5665.81773009,
#         9560.59453777,  6693.46399152,  9834.45377295])

# %%
ys_test
# Out:
# 53      6695.0
# 32      5399.0
# 78      6669.0
# 99      8949.0
# 0      13495.0
# 36      7295.0
# 52      6795.0
# 94      7299.0
# 14     24565.0
# 57     13645.0
# 119     7957.0
# 45      8916.5
# 133    12170.0
# 88      9279.0
# 20      6575.0
# 4      17450.0
# 26      7609.0
# 38      9095.0
# 62     10245.0
# Name: price, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(ys_test,yspre)
mse=mean_squared_error(ys_test,yspre)
print('MAE= ' ,mae)
print('MSE = ',mse)
# Out:
# MAE=  2910.1547867807917
# MSE =  16353420.936686506

# %%
sb.regplot(x=ys_test, y=yspre)
#sb.regplot function is used to create a scatter plot with a regression line fit to the data.
#
#Make sure to replace the example data with your actual data.

# Add labels and a title
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Regression Plot of Actual vs. Predicted Values after standardization")

# Show the plot
plt.show()

# %% [markdown]
# POLYNOMIAL REGRESSION

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Polynomial features (degree can be adjusted)
degree = 2
poly_features = PolynomialFeatures(degree=degree)
xs_train_poly = poly_features.fit_transform(xs_train)
xs_test_poly = poly_features.transform(xs_test)

# Instantiate and fit the Polynomial Regression model
poly_regressor = LinearRegression()
poly_regressor.fit(xs_train_poly, ys_train)
# Out:
# LinearRegression()

# %%
# Make predictions
ys_pred = poly_regressor.predict(xs_test_poly)
ys_pred
# Out:
# array([ 14580.20663369,   5980.52307195,   -205.99105777, 179540.97914833,
#         16500.        ,  38076.0356577 ,   2936.68245388,  -9830.48012029,
#         39907.93836738,   7987.96720219, -32587.09264693, -18826.8807943 ,
#         37193.62475859,  13147.73628358,  18813.6716529 ,  24090.52747863,
#         -7124.97928934,  15467.81510586,  22388.41030024])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mae=mean_absolute_error(ys_test,ys_pred)
mse=mean_squared_error(ys_test,ys_pred)
print('MAE= ' ,mae)
print('MSE = ',mse)
# Out:
# MAE=  21632.46014270579
# MSE =  1810385985.8290606

# %%
sb.regplot(x=ys_test, y=ys_pred)
#sb.regplot function is used to create a scatter plot with a regression line fit to the data.
#
#Make sure to replace the example data with your actual data.

# Add labels and a title
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Polynomial Regression Plot of Actual vs. Predicted Values")

# Show the plot
plt.show()
